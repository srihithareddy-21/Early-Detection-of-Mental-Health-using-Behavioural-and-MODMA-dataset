# %% [markdown]
# # NeuroScreen — Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display

# Load processed features
# X = np.load('../data/processed/features.npy')
# y = np.load('../data/processed/labels.npy')
# print(f'Shape: {X.shape}, Positive rate: {y.mean():.2%}')

# %% [markdown]
# ## Feature Distribution
# Plot MFCC statistics across classes.

# %%
# fig, axes = plt.subplots(2, 4, figsize=(16, 8))
# for i, ax in enumerate(axes.flat):
#     ax.hist(X[y==0, i], alpha=0.6, label='Non-depressed', bins=30)
#     ax.hist(X[y==1, i], alpha=0.6, label='Depressed', bins=30)
#     ax.set_title(f'Feature {i}')
#     ax.legend()
# plt.tight_layout()
# plt.show()
